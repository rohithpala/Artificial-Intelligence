# %%
import pandas as pd

# %%
data = pd.read_csv("iris.csv")
test_set = [7.2, 3.6, 5.1, 2.5]
k = 10
data
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
noOfInstances, noOfAttributes = data.shape
noOfAttributes -= 1
print("No. of Instances:", noOfInstances, "\nNo. of Attributes:", noOfAttributes)
# Out:
# No. of Instances: 150
# No. of Attributes: 4

# %%
instances = data.iloc[:, :-1]
target_values = data.iloc[:, -1]
print("Instances:\n", instances)
print("Target Values:\n", target_values)
# Out:
# Instances:
#       sepal.length  sepal.width  petal.length  petal.width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]
# Target Values:
#  0         Setosa
# 1         Setosa
# 2         Setosa
# 3         Setosa
# 4         Setosa
#          ...
# 145    Virginica
# 146    Virginica
# 147    Virginica
# 148    Virginica
# 149    Virginica
# ...

# %%
def euclideanDistance(d1, d2, l):
    distance = 0
    for i in range(l):
        distance += (d1[i]-d2[i])**2
    return distance

# %% [markdown]
# ### KNN Code

# %%
distances = []
length = len(test_set)
for i in range(noOfInstances):
    distances.append(euclideanDistance(instances.loc[i], test_set, length))

# distances
distKeys = list(enumerate(distances))
distKeys.sort(key=lambda x: x[1])

distKeys
# Out:
# [(141, 0.38),
#  (139, 0.5900000000000003),
#  (120, 0.6500000000000006),
#  (145, 0.6600000000000003),
#  (144, 0.7000000000000008),
#  (140, 0.76),
#  (112, 0.8400000000000005),
#  (124, 0.8600000000000008),
#  (115, 0.8799999999999997),
#  (110, 0.9000000000000001),
#  (109, 1.0),
#  (143, 1.0000000000000013),
#  (147, 1.1100000000000003),
#  (136, 1.1100000000000005),
#  (148, 1.1700000000000006),
#  (102, 1.1700000000000013),
#  (77, 1.2600000000000002),
#  (52, 1.3799999999999997),
#  (104, 1.4300000000000004),
#  (125, 1.4600000000000004),
#  (116, 1.5000000000000007),
#  (137, 1.54),
#  (50, 1.5699999999999998),
#  (132, 1.62),
#  (135, 1.6500000000000001),
#  (86, 1.6599999999999997),
#  (129, 1.6600000000000001),
#  (128, 1.6900000000000002),
#  (100, 1.7100000000000013),
#  (111, 1.8499999999999996),
#  (56, 1.8700000000000003),
#  (103, 2.040000000000001),
#  (130, 2.040000000000001),
#  (76, 2.1000000000000005),
#  (127, 2.100000000000001),
#  (123, 2.1500000000000004),
# ...

# %%
kNearestNeighbours = distKeys[:k]
kNearestNeighbours
# Out:
# [(141, 0.38),
#  (139, 0.5900000000000003),
#  (120, 0.6500000000000006),
#  (145, 0.6600000000000003),
#  (144, 0.7000000000000008),
#  (140, 0.76),
#  (112, 0.8400000000000005),
#  (124, 0.8600000000000008),
#  (115, 0.8799999999999997),
#  (110, 0.9000000000000001)]

# %%
classes = list(set(target_values))
classes
# Out:
# ['Virginica', 'Versicolor', 'Setosa']

# %%
# voting
votes = dict()

for class_ in classes:
    votes[class_] = 0

for i in range(k):
    label = str(target_values[kNearestNeighbours[i][0]])
    votes[label] = votes.get(label, 0) + 1

print(votes)
print("The given test set belongs to \"" + max(votes) + "\"")
# Out:
# {'Virginica': 10, 'Versicolor': 0, 'Setosa': 0}
# The given test set belongs to "Virginica"
